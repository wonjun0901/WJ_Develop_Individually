# %% [markdown]
# # PYTHON PROGRAMMING FUNDAMENTALS

# %% [markdown]
# 다음 토픽을 다룹니다. :
# - 데이터 출력
# - url 데이터 가져오기
# - datetime

# %% [markdown]
# ## 데이터를 이뿌게 출력

# %%
data = [   ['spam', 'eggs', 'lumberjack', 'knights', 'ni'],
    'spam',
    'eggs',
    'lumberjack',
    'knights',
    'ni']

# %% [markdown]
# ## URL 처리

# %% [markdown]
# ### URL 주소 형식 처리

# %% [markdown]
# https://docs.python.org/3/tutorial/index.html

# %% [markdown]
# ### URL 열기

# %% [markdown]
# http://naver.com

# %% [markdown]
# #### http://naver.com 의 페이지 소스보기와 비교해 보세요.

# %% [markdown]
# ### HTML 내에 존재하는 정보 구하기

# %% [markdown]
# ### HTML 에 포함된 모든 a 태그( 즉 링크) 의 URL 을 구하기

# %% [markdown]
# ## 네이버 영화페이지에서, 영화 제목만 뽑아내기

# %% [markdown]
# https://movie.naver.com/movie/sdb/rank/rmovie.nhn

# %% [markdown]
# ### 크롬 브라우저에서, 영화 제목에 마우스를 놓고, 마우스 오른쪽을 눌러, 검사를 합니다.

# %% [markdown]
# ![%E1%84%89%E1%85%B3%E1%84%8F%E1%85%B3%E1%84%85%E1%85%B5%E1%86%AB%E1%84%89%E1%85%A3%E1%86%BA%202019-07-21%2000.08.42.png](attachment:%E1%84%89%E1%85%B3%E1%84%8F%E1%85%B3%E1%84%85%E1%85%B5%E1%86%AB%E1%84%89%E1%85%A3%E1%86%BA%202019-07-21%2000.08.42.png)

# %% [markdown]
# ### td 안에, div 안에, a 태그로 구성되어 있음

# %% [markdown]
# ![%E1%84%89%E1%85%B3%E1%84%8F%E1%85%B3%E1%84%85%E1%85%B5%E1%86%AB%E1%84%89%E1%85%A3%E1%86%BA%202019-07-21%2000.13.59.png](attachment:%E1%84%89%E1%85%B3%E1%84%8F%E1%85%B3%E1%84%85%E1%85%B5%E1%86%AB%E1%84%89%E1%85%A3%E1%86%BA%202019-07-21%2000.13.59.png)

# %% [markdown]
# ### 제목만 추출하자
