# %% [markdown]
# # PYTHON PROGRAMMING FUNDAMENTALS

# %% [markdown]
# This Notebook will cover the following topics:
# - 파일 처리

# %% [markdown]
# # TEXT FILES
# - fopen() : 파일처리를 위한 핵심 함수로서, 파일을 연다.
# - open() : filename, mode 두개의 파라미터.
# - Modes 값은 아래와 같다 :
#
#     - "r" - Read - Default value. Opens a file for reading, error if the file does not exist
#     - "a" - Append - Opens a file for appending, creates the file if it does not exist
#     - "w" - Write - Opens a file for writing, creates the file if it does not exist
#     - "x" - Create - Creates the specified file, returns an error if the file exists
#
#
# - 텍스트 파일과, 바이너리 파일로도 나눠서 처리 가능
#
#     - "t" - Text - Default value. Text mode
#     - "b" - Binary - Binary mode (e.g. images)

# %% [markdown]
# # CSV FILES - 콤마(  ,  )로 데이터가 구분되어 저장되어 있는 형식

# %% [markdown]
# ![%E1%84%89%E1%85%B3%E1%84%8F%E1%85%B3%E1%84%85%E1%85%B5%E1%86%AB%E1%84%89%E1%85%A3%E1%86%BA%202019-07-20%2018.10.57.png](attachment:%E1%84%89%E1%85%B3%E1%84%8F%E1%85%B3%E1%84%85%E1%85%B5%E1%86%AB%E1%84%89%E1%85%A3%E1%86%BA%202019-07-20%2018.10.57.png)

# %% [markdown]
# ![%E1%84%89%E1%85%B3%E1%84%8F%E1%85%B3%E1%84%85%E1%85%B5%E1%86%AB%E1%84%89%E1%85%A3%E1%86%BA%202019-07-20%2018.09.39.png](attachment:%E1%84%89%E1%85%B3%E1%84%8F%E1%85%B3%E1%84%85%E1%85%B5%E1%86%AB%E1%84%89%E1%85%A3%E1%86%BA%202019-07-20%2018.09.39.png)

# %% [markdown]
# # JSON 데이터 처리

# %% [markdown]
# ## JSON 이란
# - ## JavaScript Object Notation, a lightweight, minimal data format used for storing and transporting data.
# - ## JSON is most often used to send data from a server to a web page or application.
# - ## JSON is a text-only format and can be written in any programming language.

# %% [markdown]
# ## JSON은, Key/Value 쌍으로 표현합니다.

# %% [markdown]
# ![%E1%84%89%E1%85%B3%E1%84%8F%E1%85%B3%E1%84%85%E1%85%B5%E1%86%AB%E1%84%89%E1%85%A3%E1%86%BA%202019-07-20%2018.17.14.png](attachment:%E1%84%89%E1%85%B3%E1%84%8F%E1%85%B3%E1%84%85%E1%85%B5%E1%86%AB%E1%84%89%E1%85%A3%E1%86%BA%202019-07-20%2018.17.14.png)

# %% [markdown]
# ## 여러개의 데이터를 처리하는 경우

# %% [markdown]
# ![%E1%84%89%E1%85%B3%E1%84%8F%E1%85%B3%E1%84%85%E1%85%B5%E1%86%AB%E1%84%89%E1%85%A3%E1%86%BA%202019-07-20%2018.14.20.png](attachment:%E1%84%89%E1%85%B3%E1%84%8F%E1%85%B3%E1%84%85%E1%85%B5%E1%86%AB%E1%84%89%E1%85%A3%E1%86%BA%202019-07-20%2018.14.20.png)

# %% [markdown]
# ### 딕셔너리를 JSON 문자열로 만들기 - encoding

# %% [markdown]
# ### JSON 문자열을, 파이썬 프로그램이 사용할 수 있도록 decoding

# %% [markdown]
# ### 참고 : 위에서 긴 문자열이 옆으로 넘어가니까, 우리가 보기 편하게 \ 을 넣어주었습니다.
